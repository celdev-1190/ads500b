# %% [markdown]
# # Final Project - House Sales Regression
#
# Austin Mallie, Cynthia Portales-Loebell, Celina Velazquez
# Shiley-Marcos School of Engineering, University of San Diego
# ADS-500B Data Science Programming
# Dr. Mohammad Yavarimanesh

# %%
This project is a linear regression analysis for house sales data in King County, Washington from May 2014 to May 2015.
# Out:
#   Cell In[38], line 1
#     This project is a linear regression analysis for house sales data in King County, Washington from May 2014 to May 2015.
#          ^
# SyntaxError: invalid syntax

# %%
This section imports the libraries that are needed.
# Out:
#   Cell In[1], line 1
#     This section imports the libraries that are needed.
#          ^
# SyntaxError: invalid syntax

# %%
pip install pandas numpy matplotlib seaborn jupyter scikit-learn
# Out:
# Requirement already satisfied: pandas in c:\users\eport\miniconda3\lib\site-packages (2.2.2)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: numpy in c:\users\eport\miniconda3\lib\site-packages (2.0.1)
# Requirement already satisfied: matplotlib in c:\users\eport\miniconda3\lib\site-packages (3.9.1)
# Requirement already satisfied: seaborn in c:\users\eport\miniconda3\lib\site-packages (0.13.2)
# Requirement already satisfied: jupyter in c:\users\eport\miniconda3\lib\site-packages (1.0.0)
# Requirement already satisfied: scikit-learn in c:\users\eport\miniconda3\lib\site-packages (1.5.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\eport\miniconda3\lib\site-packages (from pandas) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\eport\miniconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\eport\miniconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\eport\miniconda3\lib\site-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\eport\miniconda3\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\eport\miniconda3\lib\site-packages (from matplotlib) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\eport\miniconda3\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\eport\miniconda3\lib\site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=8 in c:\users\eport\miniconda3\lib\site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\eport\miniconda3\lib\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: notebook in c:\users\eport\miniconda3\lib\site-packages (from jupyter) (7.2.1)
# Requirement already satisfied: qtconsole in c:\users\eport\miniconda3\lib\site-packages (from jupyter) (5.5.2)
# Requirement already satisfied: jupyter-console in c:\users\eport\miniconda3\lib\site-packages (from jupyter) (6.6.3)
# Requirement already satisfied: nbconvert in c:\users\eport\miniconda3\lib\site-packages (from jupyter) (7.16.4)
# Requirement already satisfied: ipykernel in c:\users\eport\miniconda3\lib\site-packages (from jupyter) (6.29.5)
# Requirement already satisfied: ipywidgets in c:\users\eport\miniconda3\lib\site-packages (from jupyter) (8.1.3)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\eport\miniconda3\lib\site-packages (from scikit-learn) (1.14.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\eport\miniconda3\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\eport\miniconda3\lib\site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: six>=1.5 in c:\users\eport\miniconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: comm>=0.1.1 in c:\users\eport\miniconda3\lib\site-packages (from ipykernel->jupyter) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\eport\miniconda3\lib\site-packages (from ipykernel->jupyter) (1.8.2)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\eport\miniconda3\lib\site-packages (from ipykernel->jupyter) (8.26.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\eport\miniconda3\lib\site-packages (from ipykernel->jupyter) (8.6.2)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\eport\miniconda3\lib\site-packages (from ipykernel->jupyter) (5.7.2)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\eport\miniconda3\lib\site-packages (from ipykernel->jupyter) (0.1.7)
# Requirement already satisfied: nest-asyncio in c:\users\eport\miniconda3\lib\site-packages (from ipykernel->jupyter) (1.6.0)
# Requirement already satisfied: psutil in c:\users\eport\miniconda3\lib\site-packages (from ipykernel->jupyter) (6.0.0)
# Requirement already satisfied: pyzmq>=24 in c:\users\eport\miniconda3\lib\site-packages (from ipykernel->jupyter) (26.0.3)
# Requirement already satisfied: tornado>=6.1 in c:\users\eport\miniconda3\lib\site-packages (from ipykernel->jupyter) (6.4.1)
# Requirement already satisfied: traitlets>=5.4.0 in c:\users\eport\miniconda3\lib\site-packages (from ipykernel->jupyter) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.11 in c:\users\eport\miniconda3\lib\site-packages (from ipywidgets->jupyter) (4.0.11)
# Requirement already satisfied: jupyterlab-widgets~=3.0.11 in c:\users\eport\miniconda3\lib\site-packages (from ipywidgets->jupyter) (3.0.11)
# Requirement already satisfied: prompt-toolkit>=3.0.30 in c:\users\eport\miniconda3\lib\site-packages (from jupyter-console->jupyter) (3.0.47)
# Requirement already satisfied: pygments in c:\users\eport\miniconda3\lib\site-packages (from jupyter-console->jupyter) (2.18.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\eport\miniconda3\lib\site-packages (from nbconvert->jupyter) (4.12.3)
# Requirement already satisfied: bleach!=5.0.0 in c:\users\eport\miniconda3\lib\site-packages (from nbconvert->jupyter) (6.1.0)
# Requirement already satisfied: defusedxml in c:\users\eport\miniconda3\lib\site-packages (from nbconvert->jupyter) (0.7.1)
# Requirement already satisfied: jinja2>=3.0 in c:\users\eport\miniconda3\lib\site-packages (from nbconvert->jupyter) (3.1.4)
# Requirement already satisfied: jupyterlab-pygments in c:\users\eport\miniconda3\lib\site-packages (from nbconvert->jupyter) (0.3.0)
# Requirement already satisfied: markupsafe>=2.0 in c:\users\eport\miniconda3\lib\site-packages (from nbconvert->jupyter) (2.1.5)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\users\eport\miniconda3\lib\site-packages (from nbconvert->jupyter) (3.0.2)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\eport\miniconda3\lib\site-packages (from nbconvert->jupyter) (0.10.0)
# Requirement already satisfied: nbformat>=5.7 in c:\users\eport\miniconda3\lib\site-packages (from nbconvert->jupyter) (5.10.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\eport\miniconda3\lib\site-packages (from nbconvert->jupyter) (1.5.0)
# Requirement already satisfied: tinycss2 in c:\users\eport\miniconda3\lib\site-packages (from nbconvert->jupyter) (1.3.0)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in c:\users\eport\miniconda3\lib\site-packages (from notebook->jupyter) (2.14.1)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in c:\users\eport\miniconda3\lib\site-packages (from notebook->jupyter) (2.27.2)
# Requirement already satisfied: jupyterlab<4.3,>=4.2.0 in c:\users\eport\miniconda3\lib\site-packages (from notebook->jupyter) (4.2.3)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in c:\users\eport\miniconda3\lib\site-packages (from notebook->jupyter) (0.2.4)
# Requirement already satisfied: qtpy>=2.4.0 in c:\users\eport\miniconda3\lib\site-packages (from qtconsole->jupyter) (2.4.1)
# Requirement already satisfied: webencodings in c:\users\eport\miniconda3\lib\site-packages (from bleach!=5.0.0->nbconvert->jupyter) (0.5.1)
# Requirement already satisfied: decorator in c:\users\eport\miniconda3\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\eport\miniconda3\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.19.1)
# Requirement already satisfied: stack-data in c:\users\eport\miniconda3\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.6.2)
# Requirement already satisfied: colorama in c:\users\eport\miniconda3\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.4.6)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\eport\miniconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter) (3.10.0)
# Requirement already satisfied: pywin32>=300 in c:\users\eport\miniconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter) (306)
# Requirement already satisfied: anyio>=3.1.0 in c:\users\eport\miniconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter) (4.4.0)
# Requirement already satisfied: argon2-cffi>=21.1 in c:\users\eport\miniconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter) (23.1.0)
# Requirement already satisfied: jupyter-events>=0.9.0 in c:\users\eport\miniconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter) (0.10.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in c:\users\eport\miniconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter) (0.5.3)
# Requirement already satisfied: overrides>=5.0 in c:\users\eport\miniconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in c:\users\eport\miniconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter) (0.20.0)
# Requirement already satisfied: pywinpty>=2.0.1 in c:\users\eport\miniconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter) (2.0.13)
# Requirement already satisfied: send2trash>=1.8.2 in c:\users\eport\miniconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\eport\miniconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in c:\users\eport\miniconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter) (1.8.0)
# Requirement already satisfied: async-lru>=1.0.0 in c:\users\eport\miniconda3\lib\site-packages (from jupyterlab<4.3,>=4.2.0->notebook->jupyter) (2.0.4)
# Requirement already satisfied: httpx>=0.25.0 in c:\users\eport\miniconda3\lib\site-packages (from jupyterlab<4.3,>=4.2.0->notebook->jupyter) (0.27.0)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in c:\users\eport\miniconda3\lib\site-packages (from jupyterlab<4.3,>=4.2.0->notebook->jupyter) (2.2.5)
# Requirement already satisfied: setuptools>=40.1.0 in c:\users\eport\miniconda3\lib\site-packages (from jupyterlab<4.3,>=4.2.0->notebook->jupyter) (69.5.1)
# Requirement already satisfied: babel>=2.10 in c:\users\eport\miniconda3\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook->jupyter) (2.14.0)
# Requirement already satisfied: json5>=0.9.0 in c:\users\eport\miniconda3\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook->jupyter) (0.9.25)
# Requirement already satisfied: jsonschema>=4.18.0 in c:\users\eport\miniconda3\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook->jupyter) (4.22.0)
# Requirement already satisfied: requests>=2.31 in c:\users\eport\miniconda3\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook->jupyter) (2.32.2)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\eport\miniconda3\lib\site-packages (from nbformat>=5.7->nbconvert->jupyter) (2.20.0)
# Requirement already satisfied: wcwidth in c:\users\eport\miniconda3\lib\site-packages (from prompt-toolkit>=3.0.30->jupyter-console->jupyter) (0.2.13)
# Requirement already satisfied: soupsieve>1.2 in c:\users\eport\miniconda3\lib\site-packages (from beautifulsoup4->nbconvert->jupyter) (2.5)
# Requirement already satisfied: idna>=2.8 in c:\users\eport\miniconda3\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (3.7)
# Requirement already satisfied: sniffio>=1.1 in c:\users\eport\miniconda3\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (1.3.1)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\eport\miniconda3\lib\site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook->jupyter) (21.2.0)
# Requirement already satisfied: certifi in c:\users\eport\miniconda3\lib\site-packages (from httpx>=0.25.0->jupyterlab<4.3,>=4.2.0->notebook->jupyter) (2024.7.4)
# Requirement already satisfied: httpcore==1.* in c:\users\eport\miniconda3\lib\site-packages (from httpx>=0.25.0->jupyterlab<4.3,>=4.2.0->notebook->jupyter) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\eport\miniconda3\lib\site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab<4.3,>=4.2.0->notebook->jupyter) (0.14.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\eport\miniconda3\lib\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyter) (0.8.4)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\eport\miniconda3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook->jupyter) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\eport\miniconda3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook->jupyter) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\eport\miniconda3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook->jupyter) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\eport\miniconda3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook->jupyter) (0.19.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\users\eport\miniconda3\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (2.0.7)
# Requirement already satisfied: pyyaml>=5.3 in c:\users\eport\miniconda3\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (6.0.1)
# Requirement already satisfied: rfc3339-validator in c:\users\eport\miniconda3\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\users\eport\miniconda3\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (0.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\eport\miniconda3\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->notebook->jupyter) (2.0.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\eport\miniconda3\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->notebook->jupyter) (1.26.19)
# Requirement already satisfied: executing>=1.2.0 in c:\users\eport\miniconda3\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\eport\miniconda3\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter) (2.4.1)
# Requirement already satisfied: pure-eval in c:\users\eport\miniconda3\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter) (0.2.2)
# Requirement already satisfied: fqdn in c:\users\eport\miniconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (1.5.1)
# Requirement already satisfied: isoduration in c:\users\eport\miniconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in c:\users\eport\miniconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (2.1)
# Requirement already satisfied: uri-template in c:\users\eport\miniconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (1.3.0)
# Requirement already satisfied: webcolors>=1.11 in c:\users\eport\miniconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (24.6.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\eport\miniconda3\lib\site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook->jupyter) (1.16.0)
# Requirement already satisfied: pycparser in c:\users\eport\miniconda3\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook->jupyter) (2.21)
# Requirement already satisfied: arrow>=0.15.0 in c:\users\eport\miniconda3\lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in c:\users\eport\miniconda3\lib\site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (2.9.0.20240316)

# %%
import os
import pandas as pd
import numpy as np
import sklearn

# %% [markdown]
# ##1. Data Importing and Pre-Processing
# ### Exploratory Data Analysis
# Descriptive statistics
#
# Feature Selection
# Determine correlation to identify multicollinearity
#
# Clean date field by determining the length of the field to determine if it is consistent, then trimming the last # characters. Manage blanks in bedrooms, bathrooms, sqft_living, sqft_lot field, need to know scale of condition variable (i.e. is 5 good or bad?). Need to understand difference between sqft_living, sqft_lot, sqft_living15, sqft_lot15.

# %% [markdown]
# Determine the current working directory.

# %%
os.getcwd()
# Out:
# 'C:\\Users\\eport\\house_sales_regression'

# %% [markdown]
# Import the data file and display the records.

# %%
sales = pd.read_csv("house_sales.csv")
sales
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0       3.0       1.00
# 1      6414100192  20141209T000000  538000.0       3.0       2.25
# 2      5631500400  20150225T000000  180000.0       2.0       1.00
# 3      2487200875  20141209T000000  604000.0       4.0       3.00
# 4      1954400510  20150218T000000  510000.0       3.0       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0       3.0       2.50
# 21609  6600060120  20150223T000000  400000.0       4.0       2.50
# 21610  1523300141  20140623T000000  402101.0       2.0       0.75
# 21611   291310100  20150116T000000  400000.0       3.0       2.50
# 21612  1523300157  20141015T000000  325000.0       2.0       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0           1180.0    5650.0     1.0           0     0  ...      7
# 1           2570.0    7242.0     2.0           0     0  ...      7
# 2            770.0   10000.0     1.0           0     0  ...      6
# 3           1960.0    5000.0     1.0           0     0  ...      7
# 4           1680.0    8080.0     1.0           0     0  ...      8
# ...            ...       ...     ...         ...   ...  ...    ...
# 21608       1530.0    1131.0     3.0           0     0  ...      8
# 21609       2310.0    5813.0     2.0           0     0  ...      8
# 21610       1020.0    1350.0     2.0           0     0  ...      7
# 21611       1600.0    2388.0     2.0           0     0  ...      8
# 21612       1020.0    1076.0     2.0           0     0  ...      7
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 0            1180              0      1955             0    98178  47.5112
# 1            2170            400      1951          1991    98125  47.7210
# 2             770              0      1933             0    98028  47.7379
# 3            1050            910      1965             0    98136  47.5208
# 4            1680              0      1987             0    98074  47.6168
# ...           ...            ...       ...           ...      ...      ...
# 21608        1530              0      2009             0    98103  47.6993
# 21609        2310              0      2014             0    98146  47.5107
# 21610        1020              0      2009             0    98144  47.5944
# 21611        1600              0      2004             0    98027  47.5345
# 21612        1020              0      2008             0    98144  47.5941
#
#           long  sqft_living15  sqft_lot15
# 0     -122.257           1340        5650
# 1     -122.319           1690        7639
# 2     -122.233           2720        8062
# 3     -122.393           1360        5000
# 4     -122.045           1800        7503
# ...        ...            ...         ...
# 21608 -122.346           1530        1509
# 21609 -122.362           1830        7200
# 21610 -122.299           1020        2007
# 21611 -122.069           1410        1287
# 21612 -122.299           1020        1357
#
# [21613 rows x 21 columns]

# %% [markdown]
# Display the dimensions of the dataframe. There are 21613 records and 21 columns.

# %%
sales.shape
# Out:
# (21613, 21)

# %% [markdown]
# Display data types for columns in dataframe. There are 12 int64 (i.e. integer) variables, 8 float64 (i.e. continuous variables), and one object (i.e. string) variable. The date field is a string variable which has been imported as the incorrect type, and requires cleaning.

# %%
sales.dtypes
# Out:
# id                 int64
# date              object
# price            float64
# bedrooms         float64
# bathrooms        float64
# sqft_living      float64
# sqft_lot         float64
# floors           float64
# waterfront         int64
# view               int64
# condition          int64
# grade              int64
# sqft_above         int64
# sqft_basement      int64
# yr_built           int64
# yr_renovated       int64
# zipcode            int64
# lat              float64
# long             float64
# sqft_living15      int64
# sqft_lot15         int64
# dtype: object

# %% [markdown]
# Calculate summary statistics for the dataset.

# %%
sales.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  20479.000000  20545.000000  20503.000000
# mean   4.580302e+09  5.400881e+05      3.372821      2.113507   2081.073697
# std    2.876566e+09  3.671272e+05      0.930711      0.768913    915.043176
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.500000   1430.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1920.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  12050.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.056900e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.517982e+04      1.494309      0.007542      0.234303      3.409430
# std    4.148617e+04      0.539989      0.086517      0.766318      0.650743
# min    5.200000e+02      1.000000      0.000000      0.000000      1.000000
# 25%    5.040000e+03      1.000000      0.000000      0.000000      3.000000
# 50%    7.620000e+03      1.500000      0.000000      0.000000      3.000000
# 75%    1.070800e+04      2.000000      0.000000      0.000000      4.000000
# max    1.651359e+06      3.500000      1.000000      4.000000      5.000000
#
#               grade    sqft_above  sqft_basement      yr_built  yr_renovated  \
# count  21613.000000  21613.000000   21613.000000  21613.000000  21613.000000
# mean       7.656873   1788.390691     291.509045   1971.005136     84.402258
# std        1.175459    828.090978     442.575043     29.373411    401.679240
# min        1.000000    290.000000       0.000000   1900.000000      0.000000
# 25%        7.000000   1190.000000       0.000000   1951.000000      0.000000
# 50%        7.000000   1560.000000       0.000000   1975.000000      0.000000
# 75%        8.000000   2210.000000     560.000000   1997.000000      0.000000
# max       13.000000   9410.000000    4820.000000   2015.000000   2015.000000
#
#             zipcode           lat          long  sqft_living15     sqft_lot15
# count  21613.000000  21613.000000  21613.000000   21613.000000   21613.000000
# mean   98077.939805     47.560053   -122.213896    1986.552492   12768.455652
# std       53.505026      0.138564      0.140828     685.391304   27304.179631
# min    98001.000000     47.155900   -122.519000     399.000000     651.000000
# 25%    98033.000000     47.471000   -122.328000    1490.000000    5100.000000
# 50%    98065.000000     47.571800   -122.230000    1840.000000    7620.000000
# 75%    98118.000000     47.678000   -122.125000    2360.000000   10083.000000
# max    98199.000000     47.777600   -121.315000    6210.000000  871200.000000

# %% [markdown]
# Calculate the number of null values in each field.

# %%
sales.isnull().sum()
# Out:
# id                  0
# date                0
# price               0
# bedrooms         1134
# bathrooms        1068
# sqft_living      1110
# sqft_lot         1044
# floors              0
# waterfront          0
# view                0
# condition           0
# grade               0
# sqft_above          0
# sqft_basement       0
# yr_built            0
# yr_renovated        0
# zipcode             0
# lat                 0
# long                0
# sqft_living15       0
# sqft_lot15          0
# dtype: int64

# %%
print(sales['date'].dtype)
# Out:
# object

# %% [markdown]
# Remove the extra characters from the date field.

# %%
sales['date'].str[:-7]
# Out:
# 0        20141013
# 1        20141209
# 2        20150225
# 3        20141209
# 4        20150218
#            ...
# 21608    20140521
# 21609    20150223
# 21610    20140623
# 21611    20150116
# 21612    20141015
# Name: date, Length: 21613, dtype: object

# %% [markdown]
# Format the date field as a date data type.

# %%
sales['date'] = pd.to_datetime(sales['date'])

# %% [markdown]
# Confirm the change by checking data type of date field. The change is confirmed.

# %%
sales.dtypes
# Out:
# id                        int64
# date             datetime64[ns]
# price                   float64
# bedrooms                float64
# bathrooms               float64
# sqft_living             float64
# sqft_lot                float64
# floors                  float64
# waterfront                int64
# view                      int64
# condition                 int64
# grade                     int64
# sqft_above                int64
# sqft_basement             int64
# yr_built                  int64
# yr_renovated              int64
# zipcode                   int64
# lat                     float64
# long                    float64
# sqft_living15             int64
# sqft_lot15                int64
# dtype: object

# %% [markdown]
# Create a Pearson Correlation Coefficient matrix to determine whether there is multicollinearity between variables to determine feature selection. Variables that are highly correlated will be analyzed for removal.

# %%
sales.corr()
# Out:
#                      id      date     price  bedrooms  bathrooms  sqft_living  \
# id             1.000000  0.005577 -0.016762  0.003478   0.002095    -0.011733
# date           0.005577  1.000000 -0.004357 -0.014810  -0.034700    -0.033861
# price         -0.016762 -0.004357  1.000000  0.310823   0.526600     0.701579
# bedrooms       0.003478 -0.014810  0.310823  1.000000   0.515814     0.575974
# bathrooms      0.002095 -0.034700  0.526600  0.515814   1.000000     0.754229
# sqft_living   -0.011733 -0.033861  0.701579  0.575974   0.754229     1.000000
# sqft_lot      -0.133237  0.005438  0.088422  0.028413   0.086867     0.168363
# floors         0.018525 -0.022491  0.256794  0.178472   0.501394     0.355316
# waterfront    -0.002721  0.001356  0.266369 -0.004474   0.068412     0.107053
# view           0.011592 -0.001800  0.397293  0.082579   0.186092     0.284038
# condition     -0.023783 -0.050769  0.036362  0.028169  -0.125976    -0.059371
# grade          0.008130 -0.039912  0.667434  0.359268   0.665890     0.763833
# sqft_above    -0.010842 -0.027924  0.605567  0.478380   0.685552     0.875966
# sqft_basement -0.005151 -0.019469  0.323816  0.302168   0.284030     0.432535
# yr_built       0.021380 -0.000355  0.054012  0.156249   0.507716     0.319783
# yr_renovated  -0.016907 -0.024509  0.126434  0.019990   0.049887     0.057034
# zipcode       -0.008224  0.001404 -0.053203 -0.154337  -0.205680    -0.199637
# lat           -0.001891 -0.032856  0.307003 -0.009264   0.027456     0.051092
# long           0.020799 -0.007020  0.021626  0.130509   0.224369     0.239572
# sqft_living15 -0.002901 -0.031515  0.585379  0.392849   0.569493     0.756901
# sqft_lot15    -0.138798  0.002566  0.082447  0.025323   0.088615     0.181697
#
#                sqft_lot    floors  waterfront      view  ...     grade  \
# id            -0.133237  0.018525   -0.002721  0.011592  ...  0.008130
# date           0.005438 -0.022491    0.001356 -0.001800  ... -0.039912
# price          0.088422  0.256794    0.266369  0.397293  ...  0.667434
# bedrooms       0.028413  0.178472   -0.004474  0.082579  ...  0.359268
# bathrooms      0.086867  0.501394    0.068412  0.186092  ...  0.665890
# sqft_living    0.168363  0.355316    0.107053  0.284038  ...  0.763833
# sqft_lot       1.000000 -0.005682    0.021173  0.074342  ...  0.111713
# floors        -0.005682  1.000000    0.023698  0.029444  ...  0.458183
# waterfront     0.021173  0.023698    1.000000  0.401857  ...  0.082775
# view           0.074342  0.029444    0.401857  1.000000  ...  0.251321
# condition     -0.009154 -0.263768    0.016653  0.045990  ... -0.144674
# grade          0.111713  0.458183    0.082775  0.251321  ...  1.000000
# sqft_above     0.181152  0.523885    0.072075  0.167649  ...  0.755923
# sqft_basement  0.015569 -0.245705    0.080588  0.276947  ...  0.168392
# yr_built       0.052165  0.489319   -0.026161 -0.053440  ...  0.446963
# yr_renovated   0.008996  0.006338    0.092885  0.103917  ...  0.014414
# zipcode       -0.131311 -0.059121    0.030285  0.084827  ... -0.184862
# lat           -0.087750  0.049614   -0.014274  0.006157  ...  0.114084
# long           0.229369  0.125419   -0.041910 -0.078400  ...  0.198372
# sqft_living15  0.145112  0.279885    0.086463  0.280439  ...  0.713202
# sqft_lot15     0.728800 -0.011269    0.030703  0.072575  ...  0.119248
#
#                sqft_above  sqft_basement  yr_built  yr_renovated   zipcode  \
# id              -0.010842      -0.005151  0.021380     -0.016907 -0.008224
# date            -0.027924      -0.019469 -0.000355     -0.024509  0.001404
# price            0.605567       0.323816  0.054012      0.126434 -0.053203
# bedrooms         0.478380       0.302168  0.156249      0.019990 -0.154337
# bathrooms        0.685552       0.284030  0.507716      0.049887 -0.205680
# sqft_living      0.875966       0.432535  0.319783      0.057034 -0.199637
# sqft_lot         0.181152       0.015569  0.052165      0.008996 -0.131311
# floors           0.523885      -0.245705  0.489319      0.006338 -0.059121
# waterfront       0.072075       0.080588 -0.026161      0.092885  0.030285
# view             0.167649       0.276947 -0.053440      0.103917  0.084827
# condition       -0.158214       0.174105 -0.361417     -0.060618  0.003026
# grade            0.755923       0.168392  0.446963      0.014414 -0.184862
# sqft_above       1.000000      -0.051943  0.423898      0.023285 -0.261190
# sqft_basement   -0.051943       1.000000 -0.133124      0.071323  0.074845
# yr_built         0.423898      -0.133124  1.000000     -0.224874 -0.346869
# yr_renovated     0.023285       0.071323 -0.224874      1.000000  0.064357
# zipcode         -0.261190       0.074845 -0.346869      0.064357  1.000000
# lat             -0.000816       0.110538 -0.148122      0.029398  0.267048
# long             0.343803      -0.144765  0.409356     -0.068372 -0.564072
# sqft_living15    0.731870       0.200355  0.326229     -0.002673 -0.279033
# sqft_lot15       0.194050       0.017276  0.070958      0.007854 -0.147221
#
#                     lat      long  sqft_living15  sqft_lot15
# id            -0.001891  0.020799      -0.002901   -0.138798
# date          -0.032856 -0.007020      -0.031515    0.002566
# price          0.307003  0.021626       0.585379    0.082447
# bedrooms      -0.009264  0.130509       0.392849    0.025323
# bathrooms      0.027456  0.224369       0.569493    0.088615
# sqft_living    0.051092  0.239572       0.756901    0.181697
# sqft_lot      -0.087750  0.229369       0.145112    0.728800
# floors         0.049614  0.125419       0.279885   -0.011269
# waterfront    -0.014274 -0.041910       0.086463    0.030703
# view           0.006157 -0.078400       0.280439    0.072575
# condition     -0.014941 -0.106500      -0.092824   -0.003406
# grade          0.114084  0.198372       0.713202    0.119248
# sqft_above    -0.000816  0.343803       0.731870    0.194050
# sqft_basement  0.110538 -0.144765       0.200355    0.017276
# yr_built      -0.148122  0.409356       0.326229    0.070958
# yr_renovated   0.029398 -0.068372      -0.002673    0.007854
# zipcode        0.267048 -0.564072      -0.279033   -0.147221
# lat            1.000000 -0.135512       0.048858   -0.086419
# long          -0.135512  1.000000       0.334605    0.254451
# sqft_living15  0.048858  0.334605       1.000000    0.183192
# sqft_lot15    -0.086419  0.254451       0.183192    1.000000
#
# [21 rows x 21 columns]

# %% [markdown]
# The *sqft_living* and *sqft_lot field* appear to be very similar to the *sqft_living15* and *sqft_lot15* fields. According to the Pearson Correlation Coefficient matrix, the correlation between *sqft_living* and *sqft_living15* is 0.756901. Similarly, the correlation coefficient between *sqft_lot field* and *sqft_lot15* is 0.728800. According to Pennsylvania State University (2018), "multicollinearity exists when two or more of the predictors in a regression model are moderately or highly correlated with one another". In addition, a correlation coefficient of .8 or higher indicates multicollinearity. The values of ~.76 and ~.73 indicate moderate to high multicollinearity, and, as a result, these variables will be dropped.

# %%
sales1 = sales.drop(['sqft_living15', 'sqft_lot15'], axis=1)
sales1
# Out:
#                id       date     price  bedrooms  bathrooms  sqft_living  \
# 0      7129300520 2014-10-13  221900.0       3.0       1.00       1180.0
# 1      6414100192 2014-12-09  538000.0       3.0       2.25       2570.0
# 2      5631500400 2015-02-25  180000.0       2.0       1.00        770.0
# 3      2487200875 2014-12-09  604000.0       4.0       3.00       1960.0
# 4      1954400510 2015-02-18  510000.0       3.0       2.00       1680.0
# ...           ...        ...       ...       ...        ...          ...
# 21608   263000018 2014-05-21  360000.0       3.0       2.50       1530.0
# 21609  6600060120 2015-02-23  400000.0       4.0       2.50       2310.0
# 21610  1523300141 2014-06-23  402101.0       2.0       0.75       1020.0
# 21611   291310100 2015-01-16  400000.0       3.0       2.50       1600.0
# 21612  1523300157 2014-10-15  325000.0       2.0       0.75       1020.0
#
#        sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# 0        5650.0     1.0           0     0          3      7        1180
# 1        7242.0     2.0           0     0          3      7        2170
# 2       10000.0     1.0           0     0          3      6         770
# 3        5000.0     1.0           0     0          5      7        1050
# 4        8080.0     1.0           0     0          3      8        1680
# ...         ...     ...         ...   ...        ...    ...         ...
# 21608    1131.0     3.0           0     0          3      8        1530
# 21609    5813.0     2.0           0     0          3      8        2310
# 21610    1350.0     2.0           0     0          3      7        1020
# 21611    2388.0     2.0           0     0          3      8        1600
# 21612    1076.0     2.0           0     0          3      7        1020
#
#        sqft_basement  yr_built  yr_renovated  zipcode      lat     long
# 0                  0      1955             0    98178  47.5112 -122.257
# 1                400      1951          1991    98125  47.7210 -122.319
# 2                  0      1933             0    98028  47.7379 -122.233
# 3                910      1965             0    98136  47.5208 -122.393
# 4                  0      1987             0    98074  47.6168 -122.045
# ...              ...       ...           ...      ...      ...      ...
# 21608              0      2009             0    98103  47.6993 -122.346
# 21609              0      2014             0    98146  47.5107 -122.362
# 21610              0      2009             0    98144  47.5944 -122.299
# 21611              0      2004             0    98027  47.5345 -122.069
# 21612              0      2008             0    98144  47.5941 -122.299
#
# [21613 rows x 19 columns]

# %% [markdown]
# In the next step, *bathrooms*, *grade*, and *sqft_above* have correlation coefficients of 0.754229, 0.763833, and 0.875966, respectively, with *sqft_living*. This indicates the presence of multicollinearity with this variable. In this model, we will remove these variables, however, it would be beneficial to test a separate model using these variables in place of sqft_living to compare models.
#
# In addition, because a geospatial analysis is not part of this study, the *lat* and *long* variables will be removed.
#
# Categorical variables (i.e. *id*, *date*, *zipcode*) and the *date* field will also be removed in the next step since these values are not valid in a regression analysis.

# %%
sales2 = sales1.drop(['bathrooms', 'grade', 'sqft_above', 'lat', 'long', 'id', 'date', 'zipcode'], axis=1)
sales2
# Out:
#           price  bedrooms  sqft_living  sqft_lot  floors  waterfront  view  \
# 0      221900.0       3.0       1180.0    5650.0     1.0           0     0
# 1      538000.0       3.0       2570.0    7242.0     2.0           0     0
# 2      180000.0       2.0        770.0   10000.0     1.0           0     0
# 3      604000.0       4.0       1960.0    5000.0     1.0           0     0
# 4      510000.0       3.0       1680.0    8080.0     1.0           0     0
# ...         ...       ...          ...       ...     ...         ...   ...
# 21608  360000.0       3.0       1530.0    1131.0     3.0           0     0
# 21609  400000.0       4.0       2310.0    5813.0     2.0           0     0
# 21610  402101.0       2.0       1020.0    1350.0     2.0           0     0
# 21611  400000.0       3.0       1600.0    2388.0     2.0           0     0
# 21612  325000.0       2.0       1020.0    1076.0     2.0           0     0
#
#        condition  sqft_basement  yr_built  yr_renovated
# 0              3              0      1955             0
# 1              3            400      1951          1991
# 2              3              0      1933             0
# 3              5            910      1965             0
# 4              3              0      1987             0
# ...          ...            ...       ...           ...
# 21608          3              0      2009             0
# 21609          3              0      2014             0
# 21610          3              0      2009             0
# 21611          3              0      2004             0
# 21612          3              0      2008             0
#
# [21613 rows x 11 columns]

# %%
pd.plotting.scatter_matrix(sales2, alpha=0.2)
# Out:
# array([[<Axes: xlabel='price', ylabel='price'>,
#         <Axes: xlabel='bedrooms', ylabel='price'>,
#         <Axes: xlabel='sqft_living', ylabel='price'>,
#         <Axes: xlabel='sqft_lot', ylabel='price'>,
#         <Axes: xlabel='floors', ylabel='price'>,
#         <Axes: xlabel='waterfront', ylabel='price'>,
#         <Axes: xlabel='view', ylabel='price'>,
#         <Axes: xlabel='condition', ylabel='price'>,
#         <Axes: xlabel='sqft_basement', ylabel='price'>,
#         <Axes: xlabel='yr_built', ylabel='price'>,
#         <Axes: xlabel='yr_renovated', ylabel='price'>],
#        [<Axes: xlabel='price', ylabel='bedrooms'>,
#         <Axes: xlabel='bedrooms', ylabel='bedrooms'>,
#         <Axes: xlabel='sqft_living', ylabel='bedrooms'>,
#         <Axes: xlabel='sqft_lot', ylabel='bedrooms'>,
#         <Axes: xlabel='floors', ylabel='bedrooms'>,
#         <Axes: xlabel='waterfront', ylabel='bedrooms'>,
#         <Axes: xlabel='view', ylabel='bedrooms'>,
#         <Axes: xlabel='condition', ylabel='bedrooms'>,
#         <Axes: xlabel='sqft_basement', ylabel='bedrooms'>,
#         <Axes: xlabel='yr_built', ylabel='bedrooms'>,
#         <Axes: xlabel='yr_renovated', ylabel='bedrooms'>],
#        [<Axes: xlabel='price', ylabel='sqft_living'>,
#         <Axes: xlabel='bedrooms', ylabel='sqft_living'>,
#         <Axes: xlabel='sqft_living', ylabel='sqft_living'>,
#         <Axes: xlabel='sqft_lot', ylabel='sqft_living'>,
#         <Axes: xlabel='floors', ylabel='sqft_living'>,
#         <Axes: xlabel='waterfront', ylabel='sqft_living'>,
#         <Axes: xlabel='view', ylabel='sqft_living'>,
#         <Axes: xlabel='condition', ylabel='sqft_living'>,
#         <Axes: xlabel='sqft_basement', ylabel='sqft_living'>,
#         <Axes: xlabel='yr_built', ylabel='sqft_living'>,
#         <Axes: xlabel='yr_renovated', ylabel='sqft_living'>],
#        [<Axes: xlabel='price', ylabel='sqft_lot'>,
#         <Axes: xlabel='bedrooms', ylabel='sqft_lot'>,
#         <Axes: xlabel='sqft_living', ylabel='sqft_lot'>,
#         <Axes: xlabel='sqft_lot', ylabel='sqft_lot'>,
#         <Axes: xlabel='floors', ylabel='sqft_lot'>,
#         <Axes: xlabel='waterfront', ylabel='sqft_lot'>,
#         <Axes: xlabel='view', ylabel='sqft_lot'>,
#         <Axes: xlabel='condition', ylabel='sqft_lot'>,
#         <Axes: xlabel='sqft_basement', ylabel='sqft_lot'>,
#         <Axes: xlabel='yr_built', ylabel='sqft_lot'>,
#         <Axes: xlabel='yr_renovated', ylabel='sqft_lot'>],
#        [<Axes: xlabel='price', ylabel='floors'>,
#         <Axes: xlabel='bedrooms', ylabel='floors'>,
#         <Axes: xlabel='sqft_living', ylabel='floors'>,
#         <Axes: xlabel='sqft_lot', ylabel='floors'>,
#         <Axes: xlabel='floors', ylabel='floors'>,
#         <Axes: xlabel='waterfront', ylabel='floors'>,
#         <Axes: xlabel='view', ylabel='floors'>,
#         <Axes: xlabel='condition', ylabel='floors'>,
#         <Axes: xlabel='sqft_basement', ylabel='floors'>,
#         <Axes: xlabel='yr_built', ylabel='floors'>,
#         <Axes: xlabel='yr_renovated', ylabel='floors'>],
#        [<Axes: xlabel='price', ylabel='waterfront'>,
#         <Axes: xlabel='bedrooms', ylabel='waterfront'>,
#         <Axes: xlabel='sqft_living', ylabel='waterfront'>,
#         <Axes: xlabel='sqft_lot', ylabel='waterfront'>,
#         <Axes: xlabel='floors', ylabel='waterfront'>,
#         <Axes: xlabel='waterfront', ylabel='waterfront'>,
#         <Axes: xlabel='view', ylabel='waterfront'>,
#         <Axes: xlabel='condition', ylabel='waterfront'>,
#         <Axes: xlabel='sqft_basement', ylabel='waterfront'>,
#         <Axes: xlabel='yr_built', ylabel='waterfront'>,
#         <Axes: xlabel='yr_renovated', ylabel='waterfront'>],
#        [<Axes: xlabel='price', ylabel='view'>,
#         <Axes: xlabel='bedrooms', ylabel='view'>,
#         <Axes: xlabel='sqft_living', ylabel='view'>,
#         <Axes: xlabel='sqft_lot', ylabel='view'>,
#         <Axes: xlabel='floors', ylabel='view'>,
#         <Axes: xlabel='waterfront', ylabel='view'>,
#         <Axes: xlabel='view', ylabel='view'>,
#         <Axes: xlabel='condition', ylabel='view'>,
#         <Axes: xlabel='sqft_basement', ylabel='view'>,
#         <Axes: xlabel='yr_built', ylabel='view'>,
#         <Axes: xlabel='yr_renovated', ylabel='view'>],
#        [<Axes: xlabel='price', ylabel='condition'>,
#         <Axes: xlabel='bedrooms', ylabel='condition'>,
#         <Axes: xlabel='sqft_living', ylabel='condition'>,
#         <Axes: xlabel='sqft_lot', ylabel='condition'>,
#         <Axes: xlabel='floors', ylabel='condition'>,
#         <Axes: xlabel='waterfront', ylabel='condition'>,
#         <Axes: xlabel='view', ylabel='condition'>,
#         <Axes: xlabel='condition', ylabel='condition'>,
#         <Axes: xlabel='sqft_basement', ylabel='condition'>,
#         <Axes: xlabel='yr_built', ylabel='condition'>,
#         <Axes: xlabel='yr_renovated', ylabel='condition'>],
#        [<Axes: xlabel='price', ylabel='sqft_basement'>,
#         <Axes: xlabel='bedrooms', ylabel='sqft_basement'>,
#         <Axes: xlabel='sqft_living', ylabel='sqft_basement'>,
#         <Axes: xlabel='sqft_lot', ylabel='sqft_basement'>,
#         <Axes: xlabel='floors', ylabel='sqft_basement'>,
#         <Axes: xlabel='waterfront', ylabel='sqft_basement'>,
#         <Axes: xlabel='view', ylabel='sqft_basement'>,
#         <Axes: xlabel='condition', ylabel='sqft_basement'>,
#         <Axes: xlabel='sqft_basement', ylabel='sqft_basement'>,
#         <Axes: xlabel='yr_built', ylabel='sqft_basement'>,
#         <Axes: xlabel='yr_renovated', ylabel='sqft_basement'>],
#        [<Axes: xlabel='price', ylabel='yr_built'>,
#         <Axes: xlabel='bedrooms', ylabel='yr_built'>,
#         <Axes: xlabel='sqft_living', ylabel='yr_built'>,
#         <Axes: xlabel='sqft_lot', ylabel='yr_built'>,
#         <Axes: xlabel='floors', ylabel='yr_built'>,
#         <Axes: xlabel='waterfront', ylabel='yr_built'>,
#         <Axes: xlabel='view', ylabel='yr_built'>,
#         <Axes: xlabel='condition', ylabel='yr_built'>,
#         <Axes: xlabel='sqft_basement', ylabel='yr_built'>,
#         <Axes: xlabel='yr_built', ylabel='yr_built'>,
#         <Axes: xlabel='yr_renovated', ylabel='yr_built'>],
#        [<Axes: xlabel='price', ylabel='yr_renovated'>,
#         <Axes: xlabel='bedrooms', ylabel='yr_renovated'>,
#         <Axes: xlabel='sqft_living', ylabel='yr_renovated'>,
#         <Axes: xlabel='sqft_lot', ylabel='yr_renovated'>,
#         <Axes: xlabel='floors', ylabel='yr_renovated'>,
#         <Axes: xlabel='waterfront', ylabel='yr_renovated'>,
#         <Axes: xlabel='view', ylabel='yr_renovated'>,
#         <Axes: xlabel='condition', ylabel='yr_renovated'>,
#         <Axes: xlabel='sqft_basement', ylabel='yr_renovated'>,
#         <Axes: xlabel='yr_built', ylabel='yr_renovated'>,
#         <Axes: xlabel='yr_renovated', ylabel='yr_renovated'>]],
#       dtype=object)

# %% [markdown]
# Construct new variable for the age of the house using the yr_built variable.

# %%
sales2['age'] = 2024 - sales2['yr_built']
sales2
# Out:
#           price  bedrooms  sqft_living  sqft_lot  floors  waterfront  view  \
# 0      221900.0       3.0       1180.0    5650.0     1.0           0     0
# 1      538000.0       3.0       2570.0    7242.0     2.0           0     0
# 2      180000.0       2.0        770.0   10000.0     1.0           0     0
# 3      604000.0       4.0       1960.0    5000.0     1.0           0     0
# 4      510000.0       3.0       1680.0    8080.0     1.0           0     0
# ...         ...       ...          ...       ...     ...         ...   ...
# 21608  360000.0       3.0       1530.0    1131.0     3.0           0     0
# 21609  400000.0       4.0       2310.0    5813.0     2.0           0     0
# 21610  402101.0       2.0       1020.0    1350.0     2.0           0     0
# 21611  400000.0       3.0       1600.0    2388.0     2.0           0     0
# 21612  325000.0       2.0       1020.0    1076.0     2.0           0     0
#
#        condition  sqft_basement  yr_built  yr_renovated  age
# 0              3              0      1955             0   69
# 1              3            400      1951          1991   73
# 2              3              0      1933             0   91
# 3              5            910      1965             0   59
# 4              3              0      1987             0   37
# ...          ...            ...       ...           ...  ...
# 21608          3              0      2009             0   15
# 21609          3              0      2014             0   10
# 21610          3              0      2009             0   15
# 21611          3              0      2004             0   20
# 21612          3              0      2008             0   16
#
# [21613 rows x 12 columns]

# %% [markdown]
# Calculate recency of renovation using the yr_renovated variable if the house was renovated, otherwise, use the age of the house.

# %%
sales2['age_reno'] = np.where(sales['yr_renovated'] != 0, 2024 - sales2['yr_renovated'], sales2['age'])
sales2
# Out:
#           price  bedrooms  sqft_living  sqft_lot  floors  waterfront  view  \
# 0      221900.0       3.0       1180.0    5650.0     1.0           0     0
# 1      538000.0       3.0       2570.0    7242.0     2.0           0     0
# 2      180000.0       2.0        770.0   10000.0     1.0           0     0
# 3      604000.0       4.0       1960.0    5000.0     1.0           0     0
# 4      510000.0       3.0       1680.0    8080.0     1.0           0     0
# ...         ...       ...          ...       ...     ...         ...   ...
# 21608  360000.0       3.0       1530.0    1131.0     3.0           0     0
# 21609  400000.0       4.0       2310.0    5813.0     2.0           0     0
# 21610  402101.0       2.0       1020.0    1350.0     2.0           0     0
# 21611  400000.0       3.0       1600.0    2388.0     2.0           0     0
# 21612  325000.0       2.0       1020.0    1076.0     2.0           0     0
#
#        condition  sqft_basement  yr_built  yr_renovated  age  age_reno
# 0              3              0      1955             0   69        69
# 1              3            400      1951          1991   73        33
# 2              3              0      1933             0   91        91
# 3              5            910      1965             0   59        59
# 4              3              0      1987             0   37        37
# ...          ...            ...       ...           ...  ...       ...
# 21608          3              0      2009             0   15        15
# 21609          3              0      2014             0   10        10
# 21610          3              0      2009             0   15        15
# 21611          3              0      2004             0   20        20
# 21612          3              0      2008             0   16        16
#
# [21613 rows x 13 columns]

# %% [markdown]
# Now that we have constructed new features using the ordinal variables *yr_built* and *yr_renovated*, we can now remove these variables. In addition, to prevent multicollinearity between the newly constructed variables, *age* and *age_reno*, *age* will be dropped, and *age_reno* will be used as a proxy.

# %%
sales2 = sales2.drop(['yr_built', 'yr_renovated', 'age'], axis=1)
sales2
# Out:
#           price  bedrooms  sqft_living  sqft_lot  floors  waterfront  view  \
# 0      221900.0       3.0       1180.0    5650.0     1.0           0     0
# 1      538000.0       3.0       2570.0    7242.0     2.0           0     0
# 2      180000.0       2.0        770.0   10000.0     1.0           0     0
# 3      604000.0       4.0       1960.0    5000.0     1.0           0     0
# 4      510000.0       3.0       1680.0    8080.0     1.0           0     0
# ...         ...       ...          ...       ...     ...         ...   ...
# 21608  360000.0       3.0       1530.0    1131.0     3.0           0     0
# 21609  400000.0       4.0       2310.0    5813.0     2.0           0     0
# 21610  402101.0       2.0       1020.0    1350.0     2.0           0     0
# 21611  400000.0       3.0       1600.0    2388.0     2.0           0     0
# 21612  325000.0       2.0       1020.0    1076.0     2.0           0     0
#
#        condition  sqft_basement  age_reno
# 0              3              0        69
# 1              3            400        33
# 2              3              0        91
# 3              5            910        59
# 4              3              0        37
# ...          ...            ...       ...
# 21608          3              0        15
# 21609          3              0        10
# 21610          3              0        15
# 21611          3              0        20
# 21612          3              0        16
#
# [21613 rows x 10 columns]

# %% [markdown]
# ### Handle Missing Data
#
# There are three remaining variables (i.e. bedrooms,
# sqft_livg, 0
# sqft_0 that have missing data. The missing data represent ~5% of the total number of records. Despite the low incidence, we populate the missing values.44)

# %%
sales2[['bedrooms', 'sqft_living', 'sqft_lot']].isnull().sum()/21613
# Out:
# bedrooms       0.052468
# sqft_living    0.051358
# sqft_lot       0.048304
# dtype: float64

# %% [markdown]
# Calculate summary statistics for the variables that have missing values.

# %%
sales2[['bedrooms', 'sqft_living', 'sqft_lot']].describe()
# Out:
#            bedrooms   sqft_living      sqft_lot
# count  20479.000000  20503.000000  2.056900e+04
# mean       3.372821   2081.073697  1.517982e+04
# std        0.930711    915.043176  4.148617e+04
# min        0.000000    290.000000  5.200000e+02
# 25%        3.000000   1430.000000  5.040000e+03
# 50%        3.000000   1920.000000  7.620000e+03
# 75%        4.000000   2550.000000  1.070800e+04
# max       33.000000  12050.000000  1.651359e+06

# %% [markdown]
# Visualize the summary statistics with boxplots.

# %%
boxplot_bed = sales2.boxplot(column=['bedrooms'])

# %%
boxplot_liv = sales2.boxplot(column=['sqft_living'])

# %%
boxplot_lot = sales2.boxplot(column=['sqft_lot'])

# %% [markdown]
# To determine how to replace the null values in the bedrooms field, we consider that we can use mean, median, or mode. However, there is a large outlier that would impact the mean. We inspect this outlier to determine if it is valid or should be adjusted or removed.
#
# To determine how to handle the outlier in *bedrooms*, we will display the record that has the outlier of 33 bedrooms to determine if the price aligns with the extreme number of bedrooms or if it could be a data entry error.
#
# The price of $640,000 is around the 75th percentile. Intuition tells us that a higher number of bedrooms is correlated with a higher price, and the price seems to not align with 33 bedrooms.

# %%
sales2.loc[sales2['bedrooms'] == 33]
# Out:
#           price  bedrooms  sqft_living  sqft_lot  floors  waterfront  view  \
# 15870  640000.0      33.0       1620.0    6000.0     1.0           0     0
#
#        condition  sqft_basement  age_reno
# 15870          5            580        77

# %% [markdown]
# To understand the number of bedrooms associated with the houses sold at the highest prices, we display the records that are greater than $7,000,000.
#
# We find that there are two houses in this category, and they have five and six rooms each.

# %%
sales2.loc[sales2['price'] > 7000000]
# Out:
#           price  bedrooms  sqft_living  sqft_lot  floors  waterfront  view  \
# 3914  7062500.0       5.0      10040.0   37325.0     2.0           1     2
# 7252  7700000.0       6.0      12050.0   27600.0     2.5           0     3
#
#       condition  sqft_basement  age_reno
# 3914          3           2360        23
# 7252          4           3480        37

# %% [markdown]
# Given the discord between the price and the number of rooms, it appears that the number of bedrooms is a data entry error. We will replace this value with the most common number of bedrooms (i.e. the mode) for houses that cost between \$600,000 and \$700,000 since prices are correlated with number of bedrooms. The mode for this price range is four.

# %%
mean_600k = sales2.loc[(sales2['price'] >= 600000) & (sales2['price'] <= 700000)]
mean_600k['bedrooms'].mode()
# Out:
# 0    4.0
# Name: bedrooms, dtype: float64

# %% [markdown]
# Replace the outlier of 33 bedrooms with the mode of 4.

# %%
sales2['bedrooms'] = np.where(sales2['bedrooms'] == 33, 4, sales2['bedrooms'])
sales2
# Out:
#           price  bedrooms  sqft_living  sqft_lot  floors  waterfront  view  \
# 0      221900.0       3.0       1180.0    5650.0     1.0           0     0
# 1      538000.0       3.0       2570.0    7242.0     2.0           0     0
# 2      180000.0       2.0        770.0   10000.0     1.0           0     0
# 3      604000.0       4.0       1960.0    5000.0     1.0           0     0
# 4      510000.0       3.0       1680.0    8080.0     1.0           0     0
# ...         ...       ...          ...       ...     ...         ...   ...
# 21608  360000.0       3.0       1530.0    1131.0     3.0           0     0
# 21609  400000.0       4.0       2310.0    5813.0     2.0           0     0
# 21610  402101.0       2.0       1020.0    1350.0     2.0           0     0
# 21611  400000.0       3.0       1600.0    2388.0     2.0           0     0
# 21612  325000.0       2.0       1020.0    1076.0     2.0           0     0
#
#        condition  sqft_basement  age_reno
# 0              3              0        69
# 1              3            400        33
# 2              3              0        91
# 3              5            910        59
# 4              3              0        37
# ...          ...            ...       ...
# 21608          3              0        15
# 21609          3              0        10
# 21610          3              0        15
# 21611          3              0        20
# 21612          3              0        16
#
# [21613 rows x 10 columns]

# %%
sales2.describe()
# Out:
#               price      bedrooms   sqft_living      sqft_lot        floors  \
# count  2.161300e+04  20479.000000  20503.000000  2.056900e+04  21613.000000
# mean   5.400881e+05      3.371405   2081.073697  1.517982e+04      1.494309
# std    3.671272e+05      0.907401    915.043176  4.148617e+04      0.539989
# min    7.500000e+04      0.000000    290.000000  5.200000e+02      1.000000
# 25%    3.219500e+05      3.000000   1430.000000  5.040000e+03      1.000000
# 50%    4.500000e+05      3.000000   1920.000000  7.620000e+03      1.500000
# 75%    6.450000e+05      4.000000   2550.000000  1.070800e+04      2.000000
# max    7.700000e+06     10.000000  12050.000000  1.651359e+06      3.500000
#
#          waterfront          view     condition  sqft_basement      age_reno
# count  21613.000000  21613.000000  21613.000000   21613.000000  21613.000000
# mean       0.007542      0.234303      3.409430     291.509045     50.613982
# std        0.086517      0.766318      0.650743     442.575043     28.806854
# min        0.000000      0.000000      1.000000       0.000000      9.000000
# 25%        0.000000      0.000000      3.000000       0.000000     25.000000
# 50%        0.000000      0.000000      3.000000       0.000000     47.000000
# 75%        0.000000      0.000000      4.000000     560.000000     70.000000
# max        1.000000      4.000000      5.000000    4820.000000    124.000000

# %%
boxplot_bed2 = sales2.boxplot(column=['bedrooms'])

# %% [markdown]
# The bedrooms variable is still slightly right-skewed, so we will use the median to replace the null values.

# %%
sales2['bedrooms'] = np.where(sales2['bedrooms'].isnull(), 3, sales2['bedrooms'])

# %% [markdown]
# Check if the null values were replaced correctly.

# %%
sales2[['bedrooms']].isnull().sum()
# Out:
# bedrooms    0
# dtype: int64

# %% [markdown]
# For *sqft_living* and *sqft_lot*, we will replace the null values with the median because both variables are right-skewed, and the median is robust to outliers.

# %%
sales2['sqft_living'] = np.where(sales2['sqft_living'].isnull(), 1920, sales2['sqft_living'])

# %%
sales2[['sqft_living']].isnull().sum()
# Out:
# sqft_living    0
# dtype: int64

# %%
sales2['sqft_lot'] = np.where(sales2['sqft_lot'].isnull(), 7620, sales2['sqft_lot'])

# %%
sales2[['sqft_lot']].isnull().sum()
# Out:
# sqft_lot    0
# dtype: int64

# %% [markdown]
# ### Normalize the Data
#
# Normalization is used when the scales of the data are very different (Bhandari, 2024). To determine if that is the case with the sales2 data, we will visualized the data with boxplots.

# %%
sales2.boxplot()
# Out:
# <Axes: >

# %% [markdown]
# The difference in scale is evident; the distribution of some features is indiscernible due to the large difference in scale. Per Bhandari (2024), normalization and standardization are important for non-normal data that will be used in a regression analysis, and the following code comes from this source.

# %%
from sklearn.preprocessing import MinMaxScaler

# fit scaler on training data
norm = MinMaxScaler().fit(sales2)

# transform training data
sales2_norm = norm.transform(sales2)
print("Scaled Sales Data: \n\n")
print(sales2_norm)
# Out:
# Scaled Sales Data:
#
#
# [[0.01926557 0.3        0.07568027 ... 0.5        0.         0.52173913]
#  [0.06072131 0.3        0.19387755 ... 0.5        0.08298755 0.20869565]
#  [0.01377049 0.2        0.04081633 ... 0.5        0.         0.71304348]
#  ...
#  [0.04289849 0.2        0.06207483 ... 0.5        0.         0.05217391]
#  [0.04262295 0.3        0.11139456 ... 0.5        0.         0.09565217]
#  [0.03278689 0.2        0.06207483 ... 0.5        0.         0.06086957]]

# %% [markdown]
# Visualize the data using matplotlib since the data has changed from a Pandas dataframe to a numpy N-dimensional array (i.e. ndarray), and boxplot(), the Pandas function, no longer applies.

# %%
import matplotlib.pyplot as plt
plt.boxplot(sales2_norm)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x26cb657abd0>,
#   <matplotlib.lines.Line2D at 0x26cb657aea0>,
#   <matplotlib.lines.Line2D at 0x26cb657be90>,
#   <matplotlib.lines.Line2D at 0x26cb65e4170>,
#   <matplotlib.lines.Line2D at 0x26cb65e5280>,
#   <matplotlib.lines.Line2D at 0x26cb65e5550>,
#   <matplotlib.lines.Line2D at 0x26cb65e6600>,
#   <matplotlib.lines.Line2D at 0x26cb65e68d0>,
#   <matplotlib.lines.Line2D at 0x26cb65e78c0>,
#   <matplotlib.lines.Line2D at 0x26cb65e7b90>,
#   <matplotlib.lines.Line2D at 0x26cb66a8c80>,
#   <matplotlib.lines.Line2D at 0x26cb66a8f50>,
#   <matplotlib.lines.Line2D at 0x26cb66a9fd0>,
#   <matplotlib.lines.Line2D at 0x26cb66aa270>,
#   <matplotlib.lines.Line2D at 0x26cb66ab1a0>,
#   <matplotlib.lines.Line2D at 0x26cb3e6cef0>,
#   <matplotlib.lines.Line2D at 0x26cb3f1f1a0>,
#   <matplotlib.lines.Line2D at 0x26cb3f3e540>,
#   <matplotlib.lines.Line2D at 0x26cb3f93e30>,
#   <matplotlib.lines.Line2D at 0x26cb3fc6b40>],
#  'caps': [<matplotlib.lines.Line2D at 0x26cb657b140>,
#   <matplotlib.lines.Line2D at 0x26cb657b3b0>,
#   <matplotlib.lines.Line2D at 0x26cb65e4470>,
#   <matplotlib.lines.Line2D at 0x26cb65e4770>,
#   <matplotlib.lines.Line2D at 0x26cb65e57f0>,
#   <matplotlib.lines.Line2D at 0x26cb65e5af0>,
#   <matplotlib.lines.Line2D at 0x26cb65e6ba0>,
#   <matplotlib.lines.Line2D at 0x26cb65e6e70>,
#   <matplotlib.lines.Line2D at 0x26cb65e7e60>,
#   <matplotlib.lines.Line2D at 0x26cb66a8170>,
#   <matplotlib.lines.Line2D at 0x26cb66a91f0>,
#   <matplotlib.lines.Line2D at 0x26cb66a94f0>,
#   <matplotlib.lines.Line2D at 0x26cb66aa4b0>,
#   <matplotlib.lines.Line2D at 0x26cb66aa750>,
#   <matplotlib.lines.Line2D at 0x26cb3e6e4b0>,
#   <matplotlib.lines.Line2D at 0x26cb3eb1850>,
#   <matplotlib.lines.Line2D at 0x26cb3f3f5f0>,
#   <matplotlib.lines.Line2D at 0x26cb3f56480>,
#   <matplotlib.lines.Line2D at 0x26cb3fe8620>,
#   <matplotlib.lines.Line2D at 0x26cb3feb020>],
#  'boxes': [<matplotlib.lines.Line2D at 0x26cb645d190>,
#   <matplotlib.lines.Line2D at 0x26cb657ba10>,
#   <matplotlib.lines.Line2D at 0x26cb65e4fe0>,
#   <matplotlib.lines.Line2D at 0x26cb65e6330>,
#   <matplotlib.lines.Line2D at 0x26cb65e74a0>,
#   <matplotlib.lines.Line2D at 0x26cb66a89e0>,
#   <matplotlib.lines.Line2D at 0x26cb66a9d60>,
#   <matplotlib.lines.Line2D at 0x26cb66aaf00>,
#   <matplotlib.lines.Line2D at 0x26cb3f1dd60>,
#   <matplotlib.lines.Line2D at 0x26cb3f91d90>],
#  'medians': [<matplotlib.lines.Line2D at 0x26cb657b6b0>,
#   <matplotlib.lines.Line2D at 0x26cb65e4a70>,
#   <matplotlib.lines.Line2D at 0x26cb65e5df0>,
#   <matplotlib.lines.Line2D at 0x26cb65e7140>,
#   <matplotlib.lines.Line2D at 0x26cb66a8470>,
#   <matplotlib.lines.Line2D at 0x26cb66a97f0>,
#   <matplotlib.lines.Line2D at 0x26cb66aa9f0>,
#   <matplotlib.lines.Line2D at 0x26cb3f09820>,
#   <matplotlib.lines.Line2D at 0x26cb3f74fb0>,
#   <matplotlib.lines.Line2D at 0x26cb4000bc0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x26cb657b980>,
#   <matplotlib.lines.Line2D at 0x26cb65e4d40>,
#   <matplotlib.lines.Line2D at 0x26cb65e6090>,
#   <matplotlib.lines.Line2D at 0x26cb65e73e0>,
#   <matplotlib.lines.Line2D at 0x26cb66a8740>,
#   <matplotlib.lines.Line2D at 0x26cb66a9af0>,
#   <matplotlib.lines.Line2D at 0x26cb66aacc0>,
#   <matplotlib.lines.Line2D at 0x26cb3f0b140>,
#   <matplotlib.lines.Line2D at 0x26cb3f77740>,
#   <matplotlib.lines.Line2D at 0x26cb4001340>],
#  'means': []}

# %% [markdown]
# #References
#
# Bhandari, A. (2024, June 9). Feature scaling: Engineering, Normalization, and standardization (updated 2024). Analytics Vidhya. https://www.analyticsvidhya.com/blog/2020/04/feature-scaling-machine-learning-normalization-standardization/#:~:text=of%20the%20features!-,What%20is%20Normalization?,values%20of%20the%20feature%2C%20respectively.
# Pennsylvania State University. (2018). 10.4 - multicollinearity. 10.4 - Multicollinearity | STAT 462. https://online.stat.psu.edu/stat462/node/177/

# %% [markdown]
# <h2>Data Analysis and Visualization</h2>
# I am reviewing the measures of centrality of our updated dataset. First I am taking a look at the data types of the columns remaining. There are 5 int64 (i.e. integer) variables, 5 float64 (i.e. continuous variables).

# %%
sales2.dtypes
# Out:
# price            float64
# bedrooms         float64
# sqft_living      float64
# sqft_lot         float64
# floors           float64
# waterfront         int64
# view               int64
# condition          int64
# sqft_basement      int64
# age_reno           int64
# dtype: object

# %% [markdown]
# I want to look at the measures of centrality, however, I want to point out that some columns are categorical variables so the descriptive statistics returned does not mean anything to us. Those variables include "Waterfront", "View, and "Condition". Waterfront is binary in that the data is either a 0 or 1, either it is not a waterfront or it is. View is a number from 0 to 4, and condition is a number from 1 to 5. These are applying some sort of ranking, so looking at the Mode would be something more helpful to us than mean. In addition, bedrooms and floors are discrete variables because we cannot have half a bedroom, so things like mean or std are not helpful, but median would be. Median is the 50% row.

# %%
sales2.describe()
# Out:
#               price      bedrooms   sqft_living      sqft_lot        floors  \
# count  2.161300e+04  21613.000000  21613.000000  2.161300e+04  21613.000000
# mean   5.400881e+05      3.351918   2072.801277  1.481465e+04      1.494309
# std    3.671272e+05      0.887148    891.943876  4.050419e+04      0.539989
# min    7.500000e+04      0.000000    290.000000  5.200000e+02      1.000000
# 25%    3.219500e+05      3.000000   1450.000000  5.140000e+03      1.000000
# 50%    4.500000e+05      3.000000   1920.000000  7.620000e+03      1.500000
# 75%    6.450000e+05      4.000000   2510.000000  1.040400e+04      2.000000
# max    7.700000e+06     10.000000  12050.000000  1.651359e+06      3.500000
#
#          waterfront          view     condition  sqft_basement      age_reno
# count  21613.000000  21613.000000  21613.000000   21613.000000  21613.000000
# mean       0.007542      0.234303      3.409430     291.509045     50.613982
# std        0.086517      0.766318      0.650743     442.575043     28.806854
# min        0.000000      0.000000      1.000000       0.000000      9.000000
# 25%        0.000000      0.000000      3.000000       0.000000     25.000000
# 50%        0.000000      0.000000      3.000000       0.000000     47.000000
# 75%        0.000000      0.000000      4.000000     560.000000     70.000000
# max        1.000000      4.000000      5.000000    4820.000000    124.000000

# %%
sales2.mode()
# Out:
#       price  bedrooms  sqft_living  sqft_lot  floors  waterfront  view  \
# 0  350000.0       3.0       1920.0    7620.0     1.0         0.0   0.0
# 1  450000.0       NaN          NaN       NaN     NaN         NaN   NaN
#
#    condition  sqft_basement  age_reno
# 0        3.0            0.0      10.0
# 1        NaN            NaN       NaN

# %% [markdown]
# These histograms show interesting information on the frequency of these variables. We can visually see that the number of bedrooms seen in most of the homes in our data is 3. We also see that almost all homes are not waterfront (0). We can also see that the mode of condition is 3, followed by a 4, and then a 5.

# %%
sales2.hist(figsize=(12, 8), bins=10, edgecolor='black')
plt.suptitle('Histograms of Features')
plt.show()

# %% [markdown]
# Next I am looking at boxplots of the variables we haven't looked at yet as a boxplot: floors, waterfront, view, condition, sqft_basement, age_reno.

# %%
import seaborn as sns

# %%
columns_to_plot = ['price', 'floors', 'waterfront', 'view',	'condition', 	'sqft_basement', 	'age_reno']
    
plt.figure(figsize=(12, 8))
for i, column in enumerate(columns_to_plot):
    plt.subplot(1, len(columns_to_plot), i+1)
    sns.boxplot(sales2[column])
    plt.title(f'Boxplot of {column}')
plt.tight_layout()
plt.show()

# %% [markdown]
# Next I am disgnosing correlations between variables, and using a heat map to visualize it.

# %%
correlation_matrix = sales2.corr()
print(correlation_matrix)
# Out:
#                   price  bedrooms  sqft_living  sqft_lot    floors  \
# price          1.000000  0.309795     0.681527  0.086530  0.256794
# bedrooms       0.309795  1.000000     0.563823  0.028196  0.177943
# sqft_living    0.681527  0.563823     1.000000  0.159695  0.345290
# sqft_lot       0.086530  0.028196     0.159695  1.000000 -0.005718
# floors         0.256794  0.177943     0.345290 -0.005718  1.000000
# waterfront     0.266369 -0.005041     0.105203  0.020783  0.023698
# view           0.397293  0.082279     0.276528  0.073535  0.029444
# condition      0.036362  0.025157    -0.057751 -0.008757 -0.263768
# sqft_basement  0.323816  0.298141     0.420720  0.015346 -0.245705
# age_reno      -0.105755 -0.167055    -0.336719 -0.050705 -0.505408
#
#                waterfront      view  condition  sqft_basement  age_reno
# price            0.266369  0.397293   0.036362       0.323816 -0.105755
# bedrooms        -0.005041  0.082279   0.025157       0.298141 -0.167055
# sqft_living      0.105203  0.276528  -0.057751       0.420720 -0.336719
# sqft_lot         0.020783  0.073535  -0.008757       0.015346 -0.050705
# floors           0.023698  0.029444  -0.263768      -0.245705 -0.505408
# waterfront       1.000000  0.401857   0.016653       0.080588  0.000537
# view             0.401857  1.000000   0.045990       0.276947  0.018264
# condition        0.016653  0.045990   1.000000       0.174105  0.396358
# sqft_basement    0.080588  0.276947   0.174105       1.000000  0.102263
# age_reno         0.000537  0.018264   0.396358       0.102263  1.000000

# %% [markdown]
# On this heat map, we are seeing that price and sqft_living are highly correlated with a correlation coefficient of .68. Bedrooms and sqft_living are moderately correlated with a correlation coefficient of .56, as well as floors and age_reno are moderately negatively correlated with a coefficient of -.51. The use of a heat map for visualization is helpful to quickly find highly positively correlated variables (dark red) or highly negatively correlated variables (dark blue).

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Correlation Heatmap')
plt.show()

# %%
#This is a scatterplot of the relationship between square footage of living space and price with a regression line to show the trend.

# %%
plt.figure(figsize=(10, 6))
sns.regplot(x='sqft_living', y='price', data=sales2, scatter_kws={'s':100}, line_kws={'color':'red'})

plt.ylim(sales2['price'].min(), sales2['price'].max())

plt.title('Scatter Plot of Square footage of living space vs. Price with Regression Line')
plt.xlabel('Square footage of living space')
plt.ylabel('Price')
plt.show()

# %% [markdown]
# Based on all of the information, we can conclude that price is our dependent variable. Price is what we are looking to predict based on a variety of factors. Our independent variables are what we will use to predict or explain variations on the dependent variable. The dependent variable would be sqft_living since that is the only highly correlated variable with price.

# %%
print(sales2['price'].head())
# Out:
# 0    221900.0
# 1    538000.0
# 2    180000.0
# 3    604000.0
# 4    510000.0
# Name: price, dtype: float64
